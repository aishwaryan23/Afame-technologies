# %% [markdown]
# ## IMPORTING THE MODULE

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## READING THE CSV FILE

# %%
data=pd.read_csv('HR Data.csv')

# %% [markdown]
# ## RETRIEVING THE FIRST 5 ROWS

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## RETRIEVING THE LAST 5 ROWS

# %%
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ## CHECKING IF THERE IS ANY NULL VALUES

# %%
data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## DROPPING COLUMNS WHICH ARE UNNECESSARY

# %%
new_data=data.drop(data.columns[[6,8,10,13,16,18,21,25,27,30,34]],axis=1)
new_data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  Gender  HourlyRate  \
# ...

# %% [markdown]
# ## RENAMING THE COLUMNS

# %%
new_data.rename(columns={'EmployeeNumber': 'EmpID'}, inplace=True)
new_data.rename(columns={'Department':'Dept'},inplace=True)
new_data
# Out:
#       Age Attrition     BusinessTravel  DailyRate                    Dept  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome EducationField  EmpID  Gender  HourlyRate  ...  \
# ...

# %% [markdown]
# ### FINDING THE UNIQUE VALUES

# %%
new_data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
new_data['Gender'] = new_data['Gender'].map({'Female':'F','Male':'M'})

# %%
new_data['Dept'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
new_data['Dept']=new_data['Dept'].map({'Research & Development':'R&D','Sales':'Sales','Human Resources':'HR'})

# %%
new_data
# Out:
#       Age Attrition     BusinessTravel  DailyRate   Dept  DistanceFromHome  \
# 0      41       Yes      Travel_Rarely       1102  Sales                 1
# 1      49        No  Travel_Frequently        279    R&D                 8
# 2      37       Yes      Travel_Rarely       1373    R&D                 2
# 3      33        No  Travel_Frequently       1392    R&D                 3
# 4      27        No      Travel_Rarely        591    R&D                 2
# ...   ...       ...                ...        ...    ...               ...
# 1465   36        No  Travel_Frequently        884    R&D                23
# 1466   39        No      Travel_Rarely        613    R&D                 6
# 1467   27        No      Travel_Rarely        155    R&D                 4
# 1468   49        No  Travel_Frequently       1023  Sales                 2
# 1469   34        No      Travel_Rarely        628    R&D                 8
#
# ...

# %%
new_data.describe(include="O")
# Out:
#        Attrition BusinessTravel  Dept EducationField Gender          JobRole  \
# count       1470           1470  1470           1470   1470             1470
# unique         2              3     3              6      2                9
# top           No  Travel_Rarely   R&D  Life Sciences      M  Sales Executive
# freq        1233           1043   961            606    882              326
#
#        MaritalStatus OverTime
# count           1470     1470
# unique             3        2
# top          Married       No
# freq             673     1054

# %% [markdown]
# ## GRAPH OF ATTRITION

# %%
sns.countplot(x=new_data.Attrition)
plt.show()

# %% [markdown]
# ## FACTORS AFFECTING ATTRITION

# %%
sns.countplot(hue=new_data.Attrition,x=new_data.BusinessTravel)
plt.show()

# %%
sns.countplot(hue=new_data.Attrition,x=new_data.Dept)
plt.show()

# %%
sns.countplot(x=new_data.Attrition,hue=new_data.EducationField)
plt.show()

# %%
sns.countplot(x=new_data.Attrition,hue=new_data.Gender)
plt.show()

# %%
sns.countplot(hue=new_data.Attrition,x=new_data.OverTime)
plt.show()

# %%
plt.figure(figsize=(20,10),facecolor='white')
sns.countplot(x='JobRole',hue='Attrition',data=new_data)
plt.xlabel('JobRole',fontsize=20)
# Out:
# Text(0.5, 0, 'JobRole')
